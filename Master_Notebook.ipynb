# %% [markdown]
# <center><h1>Exploratory Data Analysis (EDA)</h1></center>

# %%
# Data Manipulation
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import warnings
from ydata_profiling import ProfileReport

# Visualizations
import seaborn as sns
import missingno as mso
import matplotlib.pyplot as plt
import plotly.express as px

# Cloud Operations
from aws_data_processor import DataProcessor

warnings.filterwarnings("ignore") 
pd.set_option('display.max_columns', None)

# AWS tables created specifically for NOAA CO2, CH4, N2O, and SF6 data within the DynamoDB environment.
co2_table = 'CO2DataNOAA'
ch4_table = 'CH4DataNOAA'
n2o_table = 'N2ODataNOAA'
sf6_table = 'SF6DataNOAA'

# %% [markdown]
# <center><h1>Carbon Dioxide (CO<sub>2</sub>)</h1></center>

# %% [markdown]
# ## Fetch Data From AWS

# %%
# Fetch and process all CO2 data from AWS database using a custom algorithm 
processor = DataProcessor(co2_table)
fetched_co2_data = processor.fetch_all_data()

# Check for empty database or DynamoDB access, otherwise proceed and process the dataframe a structured table specified in the SQL query
if fetched_co2_data.empty:
    print("No data fetched. Check DynamoDB access or table details.")
else:
    co2_df = processor.process_data(fetched_co2_data)
# Out:
# 'Full table data retrieval completed.'
#                     datetime site     ppm latitude longitude altitude  \
# 0  1968-01-16 20:04:00+00:00  NWR  322.36    40.05   -105.63   3526.0
# 1  1968-01-16 20:35:00+00:00  NWR  322.42    40.05   -105.63   3526.0
# 2  1968-01-16 21:00:00+00:00  NWR  322.65    40.05   -105.63   3526.0
# 3  1968-01-16 21:03:00+00:00  NWR  322.46    40.05   -105.63   3526.0
# 4  1968-01-16 21:30:00+00:00  NWR  322.56    40.05   -105.63   3526.0
#
#   elevation intake_height qcflag  year month day  season  \
# 0    3523.0           3.0    ...  1968     1  16  Winter
# 1    3523.0           3.0    ...  1968     1  16  Winter
# 2    3523.0           3.0    ...  1968     1  16  Winter
# 3    3523.0           3.0    ...  1968     1  16  Winter
# 4    3523.0           3.0    ...  1968     1  16  Winter
#
#         co2_change_rate  rolling_avg_ppm min_ppm_year max_ppm_year  \
# 0                   0.0       322.360000       322.36       322.36
# 1  0.060000000000002274       322.390000       322.36       322.42
# 2   0.22999999999996135       322.476667       322.36       322.65
# 3  -0.18999999999999773       322.472500       322.36       322.65
# 4   0.10000000000002274       322.490000       322.36       322.65
#
#    total_site_ppm_annual  gas
# 0                     82  CO2
# 1                     82  CO2
# 2                     82  CO2
# 3                     82  CO2
# 4                     82  CO2

# %% [markdown]
# ## Data Wrangling

# %%
co2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1217013 entries, 0 to 1217012
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   datetime               1217013 non-null  object
#  1   site                   1217013 non-null  object
#  2   ppm                    1217013 non-null  object
#  3   latitude               1217013 non-null  object
#  4   longitude              1217013 non-null  object
#  5   altitude               1217013 non-null  object
#  6   elevation              1217013 non-null  object
#  7   intake_height          1217013 non-null  object
#  8   qcflag                 1217013 non-null  object
#  9   year                   1217013 non-null  object
#  10  month                  1217013 non-null  object
#  11  day                    1217013 non-null  object
#  12  season                 1217013 non-null  object
#  13  co2_change_rate        1217013 non-null  object
#  14  rolling_avg_ppm        1217013 non-null  float64
#  15  min_ppm_year           1217013 non-null  object
#  16  max_ppm_year           1217013 non-null  object
#  17  total_site_ppm_annual  1217013 non-null  int64
#  18  gas                    1217013 non-null  object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 176.4+ MB

# %% [markdown]
# #### Data Type Coercion

# %%
# Convert datetime to datetime type
co2_df['datetime'] = pd.to_datetime(co2_df['datetime'])

# Convert numeric columns that are currently object types to float or int as appropriate
co2_df['ppm'] = pd.to_numeric(co2_df['ppm'], errors='coerce')
co2_df['latitude'] = pd.to_numeric(co2_df['latitude'], errors='coerce')
co2_df['longitude'] = pd.to_numeric(co2_df['longitude'], errors='coerce')
co2_df['altitude'] = pd.to_numeric(co2_df['altitude'], errors='coerce')
co2_df['elevation'] = pd.to_numeric(co2_df['elevation'], errors='coerce')
co2_df['intake_height'] = pd.to_numeric(co2_df['intake_height'], errors='coerce')
co2_df['co2_change_rate'] = pd.to_numeric(co2_df['co2_change_rate'], errors='coerce')
co2_df['min_ppm_year'] = pd.to_numeric(co2_df['min_ppm_year'], errors='coerce')
co2_df['max_ppm_year'] = pd.to_numeric(co2_df['max_ppm_year'], errors='coerce')

# Convert 'year', 'month', and 'day' to integer
co2_df['year'] = co2_df['year'].astype(int)
co2_df['month'] = co2_df['month'].astype(int)
co2_df['day'] = co2_df['day'].astype(int)

# 'site', 'qcflag', 'season', and 'gas' can remain as object (string) since they are categorical
co2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1217013 entries, 0 to 1217012
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   datetime               1217013 non-null  datetime64[ns, UTC]
#  1   site                   1217013 non-null  object
#  2   ppm                    1217013 non-null  float64
#  3   latitude               1217013 non-null  float64
#  4   longitude              1217013 non-null  float64
#  5   altitude               1217013 non-null  float64
#  6   elevation              1217013 non-null  float64
#  7   intake_height          1217013 non-null  float64
#  8   qcflag                 1217013 non-null  object
#  9   year                   1217013 non-null  int32
#  10  month                  1217013 non-null  int32
#  11  day                    1217013 non-null  int32
#  12  season                 1217013 non-null  object
#  13  co2_change_rate        1217013 non-null  float64
#  14  rolling_avg_ppm        1217013 non-null  float64
#  15  min_ppm_year           1217013 non-null  float64
#  16  max_ppm_year           1217013 non-null  float64
#  17  total_site_ppm_annual  1217013 non-null  int64
#  18  gas                    1217013 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(10), int32(3), int64(1), object(4)
# memory usage: 162.5+ MB

# %% [markdown]
# ## Fetch Data From PostgreSQL
#
# **To prevent accruing AWS costs, during the EDA phase I am just going to query postgres to avoid costs for reading millions of rows of data. This will also be much faster on my local machine. AWS is mainly for deployment purposes and there is no need to continue to query millions of rows on a daily basis when there is a backup database stored locally.**

# %%
engine = create_engine('postgresql://postgres:password@localhost:5432/gml_ghg')
co2_df = pd.read_sql_query('SELECT * FROM "CO2DataNOAA"', engine)
engine.dispose()

# %%
print(co2_df.shape)
co2_df.head().style.format(precision=2).set_properties(**{'border': '1.5px solid blue'}).background_gradient(cmap='coolwarm')
# Out:
# (1330405, 16)
# <style type="text/css">
# #T_5201f_row0_col0, #T_5201f_row0_col3, #T_5201f_row0_col4, #T_5201f_row0_col5, #T_5201f_row0_col6, #T_5201f_row0_col7, #T_5201f_row0_col8, #T_5201f_row0_col10, #T_5201f_row0_col11, #T_5201f_row0_col12, #T_5201f_row1_col4, #T_5201f_row1_col5, #T_5201f_row1_col6, #T_5201f_row1_col7, #T_5201f_row1_col8, #T_5201f_row1_col10, #T_5201f_row1_col11, #T_5201f_row1_col12, #T_5201f_row2_col4, #T_5201f_row2_col5, #T_5201f_row2_col6, #T_5201f_row2_col7, #T_5201f_row2_col8, #T_5201f_row2_col10, #T_5201f_row2_col11, #T_5201f_row2_col12, #T_5201f_row3_col4, #T_5201f_row3_col5, #T_5201f_row3_col6, #T_5201f_row3_col7, #T_5201f_row3_col8, #T_5201f_row3_col10, #T_5201f_row3_col11, #T_5201f_row3_col12, #T_5201f_row3_col14, #T_5201f_row4_col4, #T_5201f_row4_col5, #T_5201f_row4_col6, #T_5201f_row4_col7, #T_5201f_row4_col8, #T_5201f_row4_col10, #T_5201f_row4_col11, #T_5201f_row4_col12 {
#   border: 1.5px solid blue;
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5201f_row0_col1, #T_5201f_row0_col2, #T_5201f_row0_col9, #T_5201f_row0_col13, #T_5201f_row0_col15, #T_5201f_row1_col1, #T_5201f_row1_col2, #T_5201f_row1_col9, #T_5201f_row1_col13, #T_5201f_row1_col15, #T_5201f_row2_col1, #T_5201f_row2_col2, #T_5201f_row2_col9, #T_5201f_row2_col13, #T_5201f_row2_col15, #T_5201f_row3_col1, #T_5201f_row3_col2, #T_5201f_row3_col9, #T_5201f_row3_col13, #T_5201f_row3_col15, #T_5201f_row4_col1, #T_5201f_row4_col2, #T_5201f_row4_col9, #T_5201f_row4_col13, #T_5201f_row4_col15 {
#   border: 1.5px solid blue;
# }
# #T_5201f_row0_col14 {
#   border: 1.5px solid blue;
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_5201f_row1_col0 {
#   border: 1.5px solid blue;
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_5201f_row1_col3 {
#   border: 1.5px solid blue;
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_5201f_row1_col14 {
#   border: 1.5px solid blue;
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_5201f_row2_col0 {
#   border: 1.5px solid blue;
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5201f_row2_col3, #T_5201f_row2_col14, #T_5201f_row4_col0 {
#   border: 1.5px solid blue;
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5201f_row3_col0 {
#   border: 1.5px solid blue;
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_5201f_row3_col3 {
#   border: 1.5px solid blue;
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_5201f_row4_col3, #T_5201f_row4_col14 {
#   border: 1.5px solid blue;
#   background-color: #f7b093;
#   color: #000000;
# }
# </style>
# <table id="T_5201f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5201f_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_5201f_level0_col1" class="col_heading level0 col1" >datetime</th>
#       <th id="T_5201f_level0_col2" class="col_heading level0 col2" >site</th>
#       <th id="T_5201f_level0_col3" class="col_heading level0 col3" >ppm</th>
#       <th id="T_5201f_level0_col4" class="col_heading level0 col4" >latitude</th>
#       <th id="T_5201f_level0_col5" class="col_heading level0 col5" >longitude</th>
#       <th id="T_5201f_level0_col6" class="col_heading level0 col6" >altitude</th>
#       <th id="T_5201f_level0_col7" class="col_heading level0 col7" >elevation</th>
#       <th id="T_5201f_level0_col8" class="col_heading level0 col8" >intake_height</th>
#       <th id="T_5201f_level0_col9" class="col_heading level0 col9" >qcflag</th>
#       <th id="T_5201f_level0_col10" class="col_heading level0 col10" >year</th>
#       <th id="T_5201f_level0_col11" class="col_heading level0 col11" >month</th>
#       <th id="T_5201f_level0_col12" class="col_heading level0 col12" >day</th>
#       <th id="T_5201f_level0_col13" class="col_heading level0 col13" >season</th>
#       <th id="T_5201f_level0_col14" class="col_heading level0 col14" >co2_change_rate</th>
#       <th id="T_5201f_level0_col15" class="col_heading level0 col15" >gas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5201f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5201f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5201f_row0_col1" class="data row0 col1" >1968-01-16 12:04:00-08:00</td>
#       <td id="T_5201f_row0_col2" class="data row0 col2" >NWR</td>
#       <td id="T_5201f_row0_col3" class="data row0 col3" >322.36</td>
#       <td id="T_5201f_row0_col4" class="data row0 col4" >40.05</td>
#       <td id="T_5201f_row0_col5" class="data row0 col5" >-105.63</td>
#       <td id="T_5201f_row0_col6" class="data row0 col6" >3526.00</td>
#       <td id="T_5201f_row0_col7" class="data row0 col7" >3523.00</td>
#       <td id="T_5201f_row0_col8" class="data row0 col8" >3.00</td>
#       <td id="T_5201f_row0_col9" class="data row0 col9" >...</td>
#       <td id="T_5201f_row0_col10" class="data row0 col10" >1968</td>
#       <td id="T_5201f_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_5201f_row0_col12" class="data row0 col12" >16</td>
#       <td id="T_5201f_row0_col13" class="data row0 col13" >Winter</td>
#       <td id="T_5201f_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_5201f_row0_col15" class="data row0 col15" >CO2</td>
#     </tr>
#     <tr>
#       <th id="T_5201f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5201f_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5201f_row1_col1" class="data row1 col1" >1968-01-16 12:35:00-08:00</td>
#       <td id="T_5201f_row1_col2" class="data row1 col2" >NWR</td>
#       <td id="T_5201f_row1_col3" class="data row1 col3" >322.42</td>
#       <td id="T_5201f_row1_col4" class="data row1 col4" >40.05</td>
#       <td id="T_5201f_row1_col5" class="data row1 col5" >-105.63</td>
#       <td id="T_5201f_row1_col6" class="data row1 col6" >3526.00</td>
#       <td id="T_5201f_row1_col7" class="data row1 col7" >3523.00</td>
#       <td id="T_5201f_row1_col8" class="data row1 col8" >3.00</td>
#       <td id="T_5201f_row1_col9" class="data row1 col9" >...</td>
#       <td id="T_5201f_row1_col10" class="data row1 col10" >1968</td>
#       <td id="T_5201f_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_5201f_row1_col12" class="data row1 col12" >16</td>
#       <td id="T_5201f_row1_col13" class="data row1 col13" >Winter</td>
#       <td id="T_5201f_row1_col14" class="data row1 col14" >0.06</td>
#       <td id="T_5201f_row1_col15" class="data row1 col15" >CO2</td>
#     </tr>
#     <tr>
#       <th id="T_5201f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5201f_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5201f_row2_col1" class="data row2 col1" >1968-01-16 13:00:00-08:00</td>
#       <td id="T_5201f_row2_col2" class="data row2 col2" >NWR</td>
#       <td id="T_5201f_row2_col3" class="data row2 col3" >322.65</td>
#       <td id="T_5201f_row2_col4" class="data row2 col4" >40.05</td>
#       <td id="T_5201f_row2_col5" class="data row2 col5" >-105.63</td>
#       <td id="T_5201f_row2_col6" class="data row2 col6" >3526.00</td>
#       <td id="T_5201f_row2_col7" class="data row2 col7" >3523.00</td>
#       <td id="T_5201f_row2_col8" class="data row2 col8" >3.00</td>
#       <td id="T_5201f_row2_col9" class="data row2 col9" >...</td>
#       <td id="T_5201f_row2_col10" class="data row2 col10" >1968</td>
#       <td id="T_5201f_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_5201f_row2_col12" class="data row2 col12" >16</td>
#       <td id="T_5201f_row2_col13" class="data row2 col13" >Winter</td>
#       <td id="T_5201f_row2_col14" class="data row2 col14" >0.23</td>
#       <td id="T_5201f_row2_col15" class="data row2 col15" >CO2</td>
#     </tr>
#     <tr>
#       <th id="T_5201f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5201f_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_5201f_row3_col1" class="data row3 col1" >1968-01-16 13:03:00-08:00</td>
#       <td id="T_5201f_row3_col2" class="data row3 col2" >NWR</td>
#       <td id="T_5201f_row3_col3" class="data row3 col3" >322.46</td>
#       <td id="T_5201f_row3_col4" class="data row3 col4" >40.05</td>
#       <td id="T_5201f_row3_col5" class="data row3 col5" >-105.63

# %%
co2_df.describe().style.format(precision=2).set_properties(**{'border': '1.5px solid blue'}).background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5df40_row0_col0, #T_5df40_row0_col1, #T_5df40_row0_col2, #T_5df40_row0_col3, #T_5df40_row0_col4, #T_5df40_row0_col5, #T_5df40_row0_col6, #T_5df40_row0_col7, #T_5df40_row0_col8, #T_5df40_row0_col9, #T_5df40_row0_col10, #T_5df40_row7_col0 {
#   border: 1.5px solid blue;
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5df40_row1_col0, #T_5df40_row5_col0 {
#   border: 1.5px solid blue;
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5df40_row1_col1, #T_5df40_row1_col2, #T_5df40_row1_col3, #T_5df40_row1_col4, #T_5df40_row1_col5, #T_5df40_row1_col6, #T_5df40_row1_col7, #T_5df40_row1_col8, #T_5df40_row1_col9, #T_5df40_row1_col10, #T_5df40_row2_col1, #T_5df40_row2_col2, #T_5df40_row2_col3, #T_5df40_row2_col4, #T_5df40_row2_col5, #T_5df40_row2_col6, #T_5df40_row2_col7, #T_5df40_row2_col8, #T_5df40_row2_col9, #T_5df40_row2_col10, #T_5df40_row3_col0, #T_5df40_row3_col1, #T_5df40_row3_col2, #T_5df40_row3_col3, #T_5df40_row3_col4, #T_5df40_row3_col5, #T_5df40_row3_col6, #T_5df40_row3_col7, #T_5df40_row3_col8, #T_5df40_row3_col9, #T_5df40_row3_col10, #T_5df40_row4_col1, #T_5df40_row4_col2, #T_5df40_row4_col3, #T_5df40_row4_col4, #T_5df40_row4_col5, #T_5df40_row4_col6, #T_5df40_row4_col7, #T_5df40_row4_col8, #T_5df40_row4_col9, #T_5df40_row4_col10, #T_5df40_row5_col1, #T_5df40_row5_col2, #T_5df40_row5_col3, #T_5df40_row5_col4, #T_5df40_row5_col5, #T_5df40_row5_col6, #T_5df40_row5_col7, #T_5df40_row5_col8, #T_5df40_row5_col9, #T_5df40_row5_col10, #T_5df40_row6_col1, #T_5df40_row6_col2, #T_5df40_row6_col3, #T_5df40_row6_col4, #T_5df40_row6_col5, #T_5df40_row6_col6, #T_5df40_row6_col7, #T_5df40_row6_col8, #T_5df40_row6_col9, #T_5df40_row6_col10, #T_5df40_row7_col1, #T_5df40_row7_col2, #T_5df40_row7_col3, #T_5df40_row7_col4, #T_5df40_row7_col5, #T_5df40_row7_col6, #T_5df40_row7_col7, #T_5df40_row7_col8, #T_5df40_row7_col9, #T_5df40_row7_col10 {
#   border: 1.5px solid blue;
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5df40_row2_col0 {
#   border: 1.5px solid blue;
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_5df40_row4_col0 {
#   border: 1.5px solid blue;
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_5df40_row6_col0 {
#   border: 1.5px solid blue;
#   background-color: #f4987a;
#   color: #000000;
# }
# </style>
# <table id="T_5df40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5df40_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_5df40_level0_col1" class="col_heading level0 col1" >ppm</th>
#       <th id="T_5df40_level0_col2" class="col_heading level0 col2" >latitude</th>
#       <th id="T_5df40_level0_col3" class="col_heading level0 col3" >longitude</th>
#       <th id="T_5df40_level0_col4" class="col_heading level0 col4" >altitude</th>
#       <th id="T_5df40_level0_col5" class="col_heading level0 col5" >elevation</th>
#       <th id="T_5df40_level0_col6" class="col_heading level0 col6" >intake_height</th>
#       <th id="T_5df40_level0_col7" class="col_heading level0 col7" >year</th>
#       <th id="T_5df40_level0_col8" class="col_heading level0 col8" >month</th>
#       <th id="T_5df40_level0_col9" class="col_heading level0 col9" >day</th>
#       <th id="T_5df40_level0_col10" class="col_heading level0 col10" >co2_change_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5df40_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_5df40_row0_col0" class="data row0 col0" >1330405.00</td>
#       <td id="T_5df40_row0_col1" class="data row0 col1" >1330405.00</td>
#       <td id="T_5df40_row0_col2" class="data row0 col2" >1330405.00</td>
#       <td id="T_5df40_row0_col3" class="data row0 col3" >1330405.00</td>
#       <td id="T_5df40_row0_col4" class="data row0 col4" >1330405.00</td>
#       <td id="T_5df40_row0_col5" class="data row0 col5" >1330405.00</td>
#       <td id="T_5df40_row0_col6" class="data row0 col6" >1330405.00</td>
#       <td id="T_5df40_row0_col7" class="data row0 col7" >1330405.00</td>
#       <td id="T_5df40_row0_col8" class="data row0 col8" >1330405.00</td>
#       <td id="T_5df40_row0_col9" class="data row0 col9" >1330405.00</td>
#       <td id="T_5df40_row0_col10" class="data row0 col10" >1330405.00</td>
#     </tr>
#     <tr>
#       <th id="T_5df40_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_5df40_row1_col0" class="data row1 col0" >665203.00</td>
#       <td id="T_5df40_row1_col1" class="data row1 col1" >403.12</td>
#       <td id="T_5df40_row1_col2" class="data row1 col2" >37.50</td>
#       <td id="T_5df40_row1_col3" class="data row1 col3" >-93.36</td>
#       <td id="T_5df40_row1_col4" class="data row1 col4" >771.56</td>
#       <td id="T_5df40_row1_col5" class="data row1 col5" >624.89</td>
#       <td id="T_5df40_row1_col6" class="data row1 col6" >146.67</td>
#       <td id="T_5df40_row1_col7" class="data row1 col7" >2013.65</td>
#       <td id="T_5df40_row1_col8" class="data row1 col8" >6.50</td>
#       <td id="T_5df40_row1_col9" class="data row1 col9" >15.71</td>
#       <td id="T_5df40_row1_col10" class="data row1 col10" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_5df40_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_5df40_row2_col0" class="data row2 col0" >384054.99</td>
#       <td id="T_5df40_row2_col1" class="data row2 col1" >19.28</td>
#       <td id="T_5df40_row2_col2" class="data row2 col2" >21.15</td>
#       <td id="T_5df40_row2_col3" class="data row2 col3" >38.34</td>
#       <td id="T_5df40_row2_col4" class="data row2 col4" >798.73</td>
#       <td id="T_5df40_row2_col5" class="data row2 col5" >850.87</td>
#       <td id="T_5df40_row2_col6" class="data row2 col6" >153.88</td>
#       <td id="T_5df40_row2_col7" class="data row2 col7" >7.82</td>
#       <td id="T_5df40_row2_col8" class="data row2 col8" >3.45</td>
#       <td id="T_5df40_row2_col9" class="data row2 col9" >8.79</td>
#       <td id="T_5df40_row2_col10" class="data row2 col10" >4.07</td>
#     </tr>
#     <tr>
#       <th id="T_5df40_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_5df40_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_5df40_row3_col1" class="data row3 col1" >315.71</td>
#       <td id="T_5df40_row3_col2" class="data row3 col2" >-89.98</td>
#       <td id="T_5df40_row3_col3" class="data row3 col3" >-177.38</td>
#       <td id="T_5df40_row3_col4" class="data row3 col4" >-1.20</td>
#       <td id="T_5df40_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_5df40_row3_col6" class="data row3 col6" >-3234.20</td>
#       <td id="T_5df40_row3_col7" class="data row3 col7" >1968.00</td>
#       <td id="T_5df40_row3_col8" class="data row3 col8" >1.00</td>
#       <td id="T_5df40_row3_col9" class="data row3 col9" >1.00</td>
#       <td id="T_5df40_row3_col10" class="data row3 col10" >-132.46</td>
#     </tr>
#     <tr>
#       <th id="T_5df40_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_5df40_row4_col0" class="data row4 col0" >332602.00</td>
#       <td id="T_5df40_row4_col1" class="data row4 col1" >393.06</td>
#       <td id="T_5df40_row4_col2" class="data row4 col2" >33.41</td>
#       <td id="T_5df40_row4_col3" class="data row4 col3" >-113.72</td>
#       <td id="T_5df40_row4_col4" class="data row4 col4" >340.70</td>
#       <td id="T_5df40_row4_col5" class="data row4 col5" >52.40</td>
#       <td id="T_5df40_row4_col6" class="data row4 col6" >17.10</td>
#       <td id="T_5df40_row4_col7" class="data row4 col7" >2010.00</td>
#       <td id="T_5df40_row4_col8" class="data row4 col8" >3.00</td>
#       <td id="T_5df40_row4_col9" class="data row4 col9" >8.00</td>
#       <td id="T_5df40_row4_col10" class="data row4 col10" >-0.71</td>
#     </tr>
#     <tr>
#       <th id="T_5df40_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_5df40_row5_col0" class="data row5 col0" >665203.00</td>
#       <td id="T_5df40_row5_col1" class="data row5 col1" >404.62</td>
#       <td id="T_5df40_row5_col2" class="data row5 col2" >40.05</td>
#       <td id="T_5df40_row5_col3" class="data row5 col3" >-91.35</td>
#       <td id="T_5df40_row5_col4" class="da

# %% [markdown]
# #### Check For Missing Values

# %%
print(co2_df.isnull().sum())
# Out:
# id                 0
# datetime           0
# site               0
# ppm                0
# latitude           0
# longitude          0
# altitude           0
# elevation          0
# intake_height      0
# qcflag             0
# year               0
# month              0
# day                0
# season             0
# co2_change_rate    0
# gas                0
# dtype: int64

# %% [markdown]
# #### Check For Duplicate Values

# %%
def duplicates(df):
    before = df.shape[0]
    df = df.drop_duplicates()
    after = df.shape[0]

    total_duplicates = before - after
    print(f"There are a total of {total_duplicates} duplicates in this dataset.")
duplicates(co2_df)
# Out:
# There are a total of 0 duplicates in this dataset.

# %% [markdown]
# Since 'altitude' is just the sum of 'elevation' and 'intake_height', these features can be dropped as they don't add any useful information with regards to emission analysis. This information is useful for aerial intake operations so the user knows exactly where in the atmosphere this is being recorded from, but since all data for this project is taken from surface repos, only 'altitude' is needed to show exactly where the gas is being recorded. Also, since the qcflag was only necessary for database ingestion, it can now be dropped for the EDA phase.

# %%
co2_df = co2_df.drop(columns=['elevation', 'intake_height', 'qcflag'])

# %%
print(co2_df.shape)
co2_df.head(5).style.format(precision=2).set_properties(**{'border': '1.5px solid blue'}).background_gradient(cmap='coolwarm')
# Out:
# (1330405, 13)
# <style type="text/css">
# #T_e850d_row0_col0, #T_e850d_row0_col3, #T_e850d_row0_col4, #T_e850d_row0_col5, #T_e850d_row0_col6, #T_e850d_row0_col7, #T_e850d_row0_col8, #T_e850d_row0_col9, #T_e850d_row1_col4, #T_e850d_row1_col5, #T_e850d_row1_col6, #T_e850d_row1_col7, #T_e850d_row1_col8, #T_e850d_row1_col9, #T_e850d_row2_col4, #T_e850d_row2_col5, #T_e850d_row2_col6, #T_e850d_row2_col7, #T_e850d_row2_col8, #T_e850d_row2_col9, #T_e850d_row3_col4, #T_e850d_row3_col5, #T_e850d_row3_col6, #T_e850d_row3_col7, #T_e850d_row3_col8, #T_e850d_row3_col9, #T_e850d_row3_col11, #T_e850d_row4_col4, #T_e850d_row4_col5, #T_e850d_row4_col6, #T_e850d_row4_col7, #T_e850d_row4_col8, #T_e850d_row4_col9 {
#   border: 1.5px solid blue;
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e850d_row0_col1, #T_e850d_row0_col2, #T_e850d_row0_col10, #T_e850d_row0_col12, #T_e850d_row1_col1, #T_e850d_row1_col2, #T_e850d_row1_col10, #T_e850d_row1_col12, #T_e850d_row2_col1, #T_e850d_row2_col2, #T_e850d_row2_col10, #T_e850d_row2_col12, #T_e850d_row3_col1, #T_e850d_row3_col2, #T_e850d_row3_col10, #T_e850d_row3_col12, #T_e850d_row4_col1, #T_e850d_row4_col2, #T_e850d_row4_col10, #T_e850d_row4_col12 {
#   border: 1.5px solid blue;
# }
# #T_e850d_row0_col11 {
#   border: 1.5px solid blue;
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e850d_row1_col0 {
#   border: 1.5px solid blue;
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e850d_row1_col3 {
#   border: 1.5px solid blue;
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_e850d_row1_col11 {
#   border: 1.5px solid blue;
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_e850d_row2_col0 {
#   border: 1.5px solid blue;
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_e850d_row2_col3, #T_e850d_row2_col11, #T_e850d_row4_col0 {
#   border: 1.5px solid blue;
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e850d_row3_col0 {
#   border: 1.5px solid blue;
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_e850d_row3_col3 {
#   border: 1.5px solid blue;
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e850d_row4_col3, #T_e850d_row4_col11 {
#   border: 1.5px solid blue;
#   background-color: #f7b093;
#   color: #000000;
# }
# </style>
# <table id="T_e850d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e850d_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_e850d_level0_col1" class="col_heading level0 col1" >datetime</th>
#       <th id="T_e850d_level0_col2" class="col_heading level0 col2" >site</th>
#       <th id="T_e850d_level0_col3" class="col_heading level0 col3" >ppm</th>
#       <th id="T_e850d_level0_col4" class="col_heading level0 col4" >latitude</th>
#       <th id="T_e850d_level0_col5" class="col_heading level0 col5" >longitude</th>
#       <th id="T_e850d_level0_col6" class="col_heading level0 col6" >altitude</th>
#       <th id="T_e850d_level0_col7" class="col_heading level0 col7" >year</th>
#       <th id="T_e850d_level0_col8" class="col_heading level0 col8" >month</th>
#       <th id="T_e850d_level0_col9" class="col_heading level0 col9" >day</th>
#       <th id="T_e850d_level0_col10" class="col_heading level0 col10" >season</th>
#       <th id="T_e850d_level0_col11" class="col_heading level0 col11" >co2_change_rate</th>
#       <th id="T_e850d_level0_col12" class="col_heading level0 col12" >gas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e850d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e850d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e850d_row0_col1" class="data row0 col1" >1968-01-16 12:04:00-08:00</td>
#       <td id="T_e850d_row0_col2" class="data row0 col2" >NWR</td>
#       <td id="T_e850d_row0_col3" class="data row0 col3" >322.36</td>
#       <td id="T_e850d_row0_col4" class="data row0 col4" >40.05</td>
#       <td id="T_e850d_row0_col5" class="data row0 col5" >-105.63</td>
#       <td id="T_e850d_row0_col6" class="data row0 col6" >3526.00</td>
#       <td id="T_e850d_row0_col7" class="data row0 col7" >1968</td>
#       <td id="T_e850d_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_e850d_row0_col9" class="data row0 col9" >16</td>
#       <td id="T_e850d_row0_col10" class="data row0 col10" >Winter</td>
#       <td id="T_e850d_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_e850d_row0_col12" class="data row0 col12" >CO2</td>
#     </tr>
#     <tr>
#       <th id="T_e850d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e850d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e850d_row1_col1" class="data row1 col1" >1968-01-16 12:35:00-08:00</td>
#       <td id="T_e850d_row1_col2" class="data row1 col2" >NWR</td>
#       <td id="T_e850d_row1_col3" class="data row1 col3" >322.42</td>
#       <td id="T_e850d_row1_col4" class="data row1 col4" >40.05</td>
#       <td id="T_e850d_row1_col5" class="data row1 col5" >-105.63</td>
#       <td id="T_e850d_row1_col6" class="data row1 col6" >3526.00</td>
#       <td id="T_e850d_row1_col7" class="data row1 col7" >1968</td>
#       <td id="T_e850d_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_e850d_row1_col9" class="data row1 col9" >16</td>
#       <td id="T_e850d_row1_col10" class="data row1 col10" >Winter</td>
#       <td id="T_e850d_row1_col11" class="data row1 col11" >0.06</td>
#       <td id="T_e850d_row1_col12" class="data row1 col12" >CO2</td>
#     </tr>
#     <tr>
#       <th id="T_e850d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e850d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e850d_row2_col1" class="data row2 col1" >1968-01-16 13:00:00-08:00</td>
#       <td id="T_e850d_row2_col2" class="data row2 col2" >NWR</td>
#       <td id="T_e850d_row2_col3" class="data row2 col3" >322.65</td>
#       <td id="T_e850d_row2_col4" class="data row2 col4" >40.05</td>
#       <td id="T_e850d_row2_col5" class="data row2 col5" >-105.63</td>
#       <td id="T_e850d_row2_col6" class="data row2 col6" >3526.00</td>
#       <td id="T_e850d_row2_col7" class="data row2 col7" >1968</td>
#       <td id="T_e850d_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_e850d_row2_col9" class="data row2 col9" >16</td>
#       <td id="T_e850d_row2_col10" class="data row2 col10" >Winter</td>
#       <td id="T_e850d_row2_col11" class="data row2 col11" >0.23</td>
#       <td id="T_e850d_row2_col12" class="data row2 col12" >CO2</td>
#     </tr>
#     <tr>
#       <th id="T_e850d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e850d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e850d_row3_col1" class="data row3 col1" >1968-01-16 13:03:00-08:00</td>
#       <td id="T_e850d_row3_col2" class="data row3 col2" >NWR</td>
#       <td id="T_e850d_row3_col3" class="data row3 col3" >322.46</td>
#       <td id="T_e850d_row3_col4" class="data row3 col4" >40.05</td>
#       <td id="T_e850d_row3_col5" class="data row3 col5" >-105.63</td>
#       <td id="T_e850d_row3_col6" class="data row3 col6" >3526.00</td>
#       <td id="T_e850d_row3_col7" class="data row3 col7" >1968</td>
#       <td id="T_e850d_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_e850d_row3_col9" class="data row3 col9" >16</td>
#       <td id="T_e850d_row3_col10" class="data row3 col10" >Winter</td>
#       <td id="T_e850d_row3_col11" class="data row3 col11" >-0.19</td>
#       <td id="T_e850d_row3_col12" class="data row3 col12" >CO2</td>
#     </tr>
#     <tr>
#       <th id="T_e850d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e850d_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e850d_row4_col1" class="data row4 col1" >1968-01-16 13:30:00-08:00</td>
#       <td id="T_e850d_row4_col2" class="data row4 col2" >NWR</td>
#       <td id="T_e850d_row4_col3" class="data row4 col3" >322.56</td>
#       <td id="T_e850d_row4_col4" class="data row4 col4" >40.05</td>
#       <td id="T_e850d_row4_col5" class="data row4 col5" >-105.63</td>
#       <td id="T_e850d_row4_col6" class="data row4 col6" >3526.00</td>
#       <td id="T_e850d_row4_col7" class="data row4 col7" >1968</td>
#       <td id="T_e850d_row4_col8" class="data row4 col8" >1</t

# %% [markdown]
# ## Time Series Analysis
