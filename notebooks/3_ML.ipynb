# %% [markdown]
# <center><h1>Machine Learning Model Pipeline</h1></center>

# %%
# Data Manipulation
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# System Settings
import warnings
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath('../atmoseer'))
sys.path.append(os.path.abspath('../utils'))
warnings.filterwarnings("ignore")

# Custom Database Operations
from utils.postgres_processor import load_table

# %%
co2_df = load_table("CO2DataNOAA", "postgres", "Godragons6")
co2_df.head().style.format(precision=2).set_properties(**{'border': '1.5px solid blue'}).background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_fd2fe_row0_col0, #T_fd2fe_row0_col1, #T_fd2fe_row0_col9, #T_fd2fe_row0_col11, #T_fd2fe_row1_col0, #T_fd2fe_row1_col1, #T_fd2fe_row1_col9, #T_fd2fe_row1_col11, #T_fd2fe_row2_col0, #T_fd2fe_row2_col1, #T_fd2fe_row2_col9, #T_fd2fe_row2_col11, #T_fd2fe_row3_col0, #T_fd2fe_row3_col1, #T_fd2fe_row3_col9, #T_fd2fe_row3_col11, #T_fd2fe_row4_col0, #T_fd2fe_row4_col1, #T_fd2fe_row4_col9, #T_fd2fe_row4_col11 {
#   border: 1.5px solid blue;
# }
# #T_fd2fe_row0_col2 {
#   border: 1.5px solid blue;
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_fd2fe_row0_col3, #T_fd2fe_row0_col4, #T_fd2fe_row0_col5, #T_fd2fe_row0_col6, #T_fd2fe_row0_col7, #T_fd2fe_row0_col12, #T_fd2fe_row0_col14, #T_fd2fe_row0_col15, #T_fd2fe_row0_col16, #T_fd2fe_row0_col17, #T_fd2fe_row1_col2, #T_fd2fe_row1_col3, #T_fd2fe_row1_col4, #T_fd2fe_row1_col5, #T_fd2fe_row1_col6, #T_fd2fe_row1_col7, #T_fd2fe_row1_col12, #T_fd2fe_row1_col14, #T_fd2fe_row1_col15, #T_fd2fe_row1_col16, #T_fd2fe_row1_col17, #T_fd2fe_row2_col3, #T_fd2fe_row2_col4, #T_fd2fe_row2_col5, #T_fd2fe_row2_col6, #T_fd2fe_row2_col14, #T_fd2fe_row2_col15, #T_fd2fe_row2_col16, #T_fd2fe_row3_col3, #T_fd2fe_row3_col4, #T_fd2fe_row3_col5, #T_fd2fe_row3_col6, #T_fd2fe_row3_col8, #T_fd2fe_row3_col13, #T_fd2fe_row3_col14, #T_fd2fe_row3_col15, #T_fd2fe_row3_col16, #T_fd2fe_row4_col3, #T_fd2fe_row4_col4, #T_fd2fe_row4_col5, #T_fd2fe_row4_col6, #T_fd2fe_row4_col10, #T_fd2fe_row4_col13, #T_fd2fe_row4_col14, #T_fd2fe_row4_col15, #T_fd2fe_row4_col16 {
#   border: 1.5px solid blue;
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fd2fe_row0_col8 {
#   border: 1.5px solid blue;
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_fd2fe_row0_col10 {
#   border: 1.5px solid blue;
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_fd2fe_row0_col13, #T_fd2fe_row1_col13, #T_fd2fe_row2_col8, #T_fd2fe_row2_col10, #T_fd2fe_row3_col2, #T_fd2fe_row3_col7, #T_fd2fe_row3_col12, #T_fd2fe_row3_col17, #T_fd2fe_row4_col7, #T_fd2fe_row4_col12, #T_fd2fe_row4_col17 {
#   border: 1.5px solid blue;
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fd2fe_row1_col8 {
#   border: 1.5px solid blue;
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_fd2fe_row1_col10 {
#   border: 1.5px solid blue;
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_fd2fe_row2_col2 {
#   border: 1.5px solid blue;
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_fd2fe_row2_col7 {
#   border: 1.5px solid blue;
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_fd2fe_row2_col12 {
#   border: 1.5px solid blue;
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_fd2fe_row2_col13 {
#   border: 1.5px solid blue;
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_fd2fe_row2_col17 {
#   border: 1.5px solid blue;
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_fd2fe_row3_col10 {
#   border: 1.5px solid blue;
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_fd2fe_row4_col2 {
#   border: 1.5px solid blue;
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_fd2fe_row4_col8 {
#   border: 1.5px solid blue;
#   background-color: #a5c3fe;
#   color: #000000;
# }
# </style>
# <table id="T_fd2fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd2fe_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_fd2fe_level0_col1" class="col_heading level0 col1" >site</th>
#       <th id="T_fd2fe_level0_col2" class="col_heading level0 col2" >ppm</th>
#       <th id="T_fd2fe_level0_col3" class="col_heading level0 col3" >latitude</th>
#       <th id="T_fd2fe_level0_col4" class="col_heading level0 col4" >longitude</th>
#       <th id="T_fd2fe_level0_col5" class="col_heading level0 col5" >altitude</th>
#       <th id="T_fd2fe_level0_col6" class="col_heading level0 col6" >year</th>
#       <th id="T_fd2fe_level0_col7" class="col_heading level0 col7" >month</th>
#       <th id="T_fd2fe_level0_col8" class="col_heading level0 col8" >day</th>
#       <th id="T_fd2fe_level0_col9" class="col_heading level0 col9" >season</th>
#       <th id="T_fd2fe_level0_col10" class="col_heading level0 col10" >co2_change_rate</th>
#       <th id="T_fd2fe_level0_col11" class="col_heading level0 col11" >gas</th>
#       <th id="T_fd2fe_level0_col12" class="col_heading level0 col12" >month_sin</th>
#       <th id="T_fd2fe_level0_col13" class="col_heading level0 col13" >month_cos</th>
#       <th id="T_fd2fe_level0_col14" class="col_heading level0 col14" >ppm_lag_14</th>
#       <th id="T_fd2fe_level0_col15" class="col_heading level0 col15" >ppm_lag_30</th>
#       <th id="T_fd2fe_level0_col16" class="col_heading level0 col16" >ppm_lag_365</th>
#       <th id="T_fd2fe_level0_col17" class="col_heading level0 col17" >biomass_density</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd2fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd2fe_row0_col0" class="data row0 col0" >1968-01-16 00:00:00</td>
#       <td id="T_fd2fe_row0_col1" class="data row0 col1" >NWR</td>
#       <td id="T_fd2fe_row0_col2" class="data row0 col2" >324.38</td>
#       <td id="T_fd2fe_row0_col3" class="data row0 col3" >40.05</td>
#       <td id="T_fd2fe_row0_col4" class="data row0 col4" >-105.63</td>
#       <td id="T_fd2fe_row0_col5" class="data row0 col5" >3526.00</td>
#       <td id="T_fd2fe_row0_col6" class="data row0 col6" >1968</td>
#       <td id="T_fd2fe_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_fd2fe_row0_col8" class="data row0 col8" >16</td>
#       <td id="T_fd2fe_row0_col9" class="data row0 col9" >Winter</td>
#       <td id="T_fd2fe_row0_col10" class="data row0 col10" >1.50</td>
#       <td id="T_fd2fe_row0_col11" class="data row0 col11" >CO2</td>
#       <td id="T_fd2fe_row0_col12" class="data row0 col12" >0.50</td>
#       <td id="T_fd2fe_row0_col13" class="data row0 col13" >0.87</td>
#       <td id="T_fd2fe_row0_col14" class="data row0 col14" >324.38</td>
#       <td id="T_fd2fe_row0_col15" class="data row0 col15" >324.38</td>
#       <td id="T_fd2fe_row0_col16" class="data row0 col16" >324.38</td>
#       <td id="T_fd2fe_row0_col17" class="data row0 col17" >328352893.44</td>
#     </tr>
#     <tr>
#       <th id="T_fd2fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd2fe_row1_col0" class="data row1 col0" >1968-01-17 00:00:00</td>
#       <td id="T_fd2fe_row1_col1" class="data row1 col1" >NWR</td>
#       <td id="T_fd2fe_row1_col2" class="data row1 col2" >323.69</td>
#       <td id="T_fd2fe_row1_col3" class="data row1 col3" >40.05</td>
#       <td id="T_fd2fe_row1_col4" class="data row1 col4" >-105.63</td>
#       <td id="T_fd2fe_row1_col5" class="data row1 col5" >3526.00</td>
#       <td id="T_fd2fe_row1_col6" class="data row1 col6" >1968</td>
#       <td id="T_fd2fe_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_fd2fe_row1_col8" class="data row1 col8" >17</td>
#       <td id="T_fd2fe_row1_col9" class="data row1 col9" >Winter</td>
#       <td id="T_fd2fe_row1_col10" class="data row1 col10" >-0.16</td>
#       <td id="T_fd2fe_row1_col11" class="data row1 col11" >CO2</td>
#       <td id="T_fd2fe_row1_col12" class="data row1 col12" >0.50</td>
#       <td id="T_fd2fe_row1_col13" class="data row1 col13" >0.87</td>
#       <td id="T_fd2fe_row1_col14" class="data row1 col14" >324.38</td>
#       <td id="T_fd2fe_row1_col15" class="data row1 col15" >324.38</td>
#       <td id="T_fd2fe_row1_col16" class="data row1 col16" >324.38</td>
#       <td id="T_fd2fe_row1_col17" class="data row1 col17" >328352893.44</td>
#     </tr>
#     <tr>
#       <th id="T_fd2fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd2fe_row2_col0" class="data row2 col0" >1968-02-29 00:00:00</td>
#       <td id="T_fd2fe_row2_col1" class="data row2 col1" >NWR</td>
#       <td id="T_fd2fe_row2_col2" class="data row2 col2" >325.53</td>
#       <td id="T_fd2fe_row2_col3" class="data row2 col3" >40.05</td>
#       <td id="T_fd2fe_row2_col4" class="data row2 col4" >-105.63</td>
#       <td id="T_fd2fe_row2_col5" class="data row2 col5" >3526.00</td>
#       <td id="T_fd2fe_row2_col6" class="data row2 col6" >1968</td>
#       <td id="T_fd2fe_row2_col7" class="data row2 co
